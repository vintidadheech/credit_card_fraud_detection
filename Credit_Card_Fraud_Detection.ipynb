# %% [markdown]
# <a href="https://colab.research.google.com/github/nandiniranjansinha/Credit-Card-Fraud-Detection/blob/main/Credit_Card_Fraud_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing the Dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# loading the dataset to a Pandas DataFrame
credit_card_data = pd.read_csv('/content/creditcard.csv')

# %%
# first 5 rows of the dataset
credit_card_data.head()
# amount is in USD
# 1 -> Fraudulent
# 0 -> Real/Legit
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 49605  44132 -1.211298 -0.450385  1.440502  0.354908 -0.408886  1.636777
# 49606  44132  1.176642  0.154754  0.246080  0.800814 -0.590838 -1.487705
# 49607  44133 -1.103844  0.186527  1.568397  1.307678  0.316942  0.290415
# 49608  44134 -0.262018  0.851831  1.459865  1.057694 -0.725526  0.274325
# 49609  44135 -4.719790 -4.249875  1.850000       NaN       NaN       NaN
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 49605 -0.951234  1.185703 -1.020024  ...  0.086607  0.526001  0.191522
# 49606  0.336949 -0.316725 -0.047056  ... -0.008572 -0.105115 -0.017629
# 49607  1.147621 -0.222930  0.000022  ... -0.160645  0.468407  0.389831
# 49608  1.750817 -1.097029  0.439934  ... -0.272138  0.032569 -0.141121
# 49609       NaN       NaN       NaN  ...       NaN       NaN       NaN
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
# dataset information
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49610 entries, 0 to 49609
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    49610 non-null  int64
#  1   V1      49610 non-null  float64
#  2   V2      49610 non-null  float64
#  3   V3      49610 non-null  float64
#  4   V4      49609 non-null  float64
#  5   V5      49609 non-null  float64
#  6   V6      49609 non-null  float64
#  7   V7      49609 non-null  float64
#  8   V8      49609 non-null  float64
#  9   V9      49609 non-null  float64
#  10  V10     49609 non-null  float64
#  11  V11     49609 non-null  float64
#  12  V12     49609 non-null  float64
#  13  V13     49609 non-null  float64
#  14  V14     49609 non-null  float64
#  15  V15     49609 non-null  float64
#  16  V16     49609 non-null  float64
#  17  V17     49609 non-null  float64
#  18  V18     49609 non-null  float64
#  19  V19     49609 non-null  float64
# ...

# %%
# checking the number of missing values in each column
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        1
# V5        1
# V6        1
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
# distribution oflegit transaction nd fraudulent transaction
credit_card_data['Class'].value_counts()
# Out:
# 0.0    49461
# 1.0      148
# Name: Class, dtype: int64

# %%
# very unbalanced data
# it needs to be trained
# the dataset is unbalanced so we can't feed this directly

# %% [markdown]
# This Dataset is highly unbalanced

# %% [markdown]
# 0 --> Normal Transaction
#
# 1 --> Fraudulent Transaction

# %%
# separating the data for analysis
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (49461, 31)
# (148, 31)

# %%
# statistical measures of the data
legit.Amount.describe()
# std -> standard deviation
# Out:
# count    49461.000000
# mean        93.099593
# std        253.325102
# min          0.000000
# 25%          7.680000
# 50%         25.000000
# 75%         85.000000
# max      12910.930000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     148.000000
# mean      100.170676
# std       233.347471
# min         0.000000
# 25%         1.000000
# 50%         9.560000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
# compare the values for both transactions
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    28809.010473 -0.220239 -0.003947   0.726173  0.167967 -0.240785
# 1.0    26877.182432 -7.675017  5.448919 -10.398242  5.939649 -5.681176
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.111250 -0.096470  0.042413  0.134593  ...  0.046113 -0.031134
# 1.0   -2.280722 -8.068966  3.739332 -3.587074  ...  0.470319  0.886835
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.106800 -0.039391  0.008275  0.135623  0.020410  0.003001  0.004455
# 1.0   -0.225326 -0.284732 -0.084733  0.246743  0.155479  0.603171  0.030658
#
#            Amount
# Class
# 0.0     93.099593
# 1.0    100.170676
#
# [2 rows x 30 columns]

# %% [markdown]
# Under-Sampling

# %% [markdown]
# Build a sample dataset containing similar distribution of normal transactions and fraudulent transactions

# %% [markdown]
# Number of Fraudulent Transactions -> 148

# %%
legit_sample = legit.sample(n=148) #random sampling

# %% [markdown]
# Concatenating two DataFrames

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)
# axis = 0 -> 148 values added below legit sample (row-wise)
# axis = 1 -> column-wise

# %%
new_dataset.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 10601  17708 -1.147207  1.403443  1.039369  1.190107  0.544046  1.963182
# 2366    1911  1.550736 -1.044668  0.388104 -1.721063 -1.100930  0.208485
# 3229    2796 -0.458806  0.600392  1.174742 -2.149494  0.294435 -0.832432
# 37099  38806 -0.789207  0.676912  1.951561  1.536374 -0.537135  1.570921
# 18728  29721  1.277573 -0.536155 -0.258179 -1.047285  1.192855  3.719173
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 10601 -0.159004  1.059518  0.720213  ... -0.034500  0.554594  0.001219
# 2366  -1.302652  0.009271 -1.966017  ... -0.074752  0.246098 -0.167126
# 3229   0.980201 -0.155998  0.594867  ...  0.150233  0.798207 -0.250697
# 37099 -0.617529  1.147034  0.307826  ... -0.197972 -0.255916  0.064585
# 18728 -1.436137  1.048373  0.692734  ...  0.145266  0.320687 -0.040664
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 46909  42985 -4.075975  0.963031 -5.076070  4.955963 -0.161437 -2.832663
# 46918  42988 -4.423508  1.648048 -6.934388  4.894601 -5.078131  0.010849
# 46998  43028 -1.109646  0.811069 -1.138135  0.935265 -2.330248 -0.116106
# 47802  43369 -3.365319  2.426503 -3.752227  0.276017 -2.305870 -1.961578
# 48094  43494 -1.278138  0.716242 -1.143279  0.217805 -1.293890 -1.168952
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 46909 -7.619765  1.618895 -2.992092  ...  1.030738  0.165328 -1.017502
# 46918 -3.409096  1.409291 -3.260672  ...  0.698359  0.487478  1.228698
# 46998 -1.621986  0.458028 -0.912189  ...  0.641594  0.841755  0.176728
# 47802 -3.029283 -1.674462  0.183961  ...  2.070008 -0.512626 -0.248502
# 48094 -2.564182  0.204532 -1.611155  ...  0.490183  0.470427 -0.126261
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset['Class'].value_counts()
# now we have uniformly distributed data
# Out:
# 0.0    148
# 1.0    148
# Name: Class, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    27724.871622 -0.266158 -0.002510   0.745369  0.095146 -0.349750
# 1.0    26877.182432 -7.675017  5.448919 -10.398242  5.939649 -5.681176
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.057926 -0.158931  0.161386  0.068068  ... -0.029816 -0.037114
# 1.0   -2.280722 -8.068966  3.739332 -3.587074  ...  0.470319  0.886835
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.017468 -0.024049 -0.008667  0.139845 -0.023843  0.004619 -0.025062
# 1.0   -0.225326 -0.284732 -0.084733  0.246743  0.155479  0.603171  0.030658
#
#            Amount
# Class
# 0.0     74.951959
# 1.0    100.170676
#
# [2 rows x 30 columns]

# %% [markdown]
# Splitting the data into Features & Targets

# %%
X = new_dataset.drop(columns='Class', axis=1)
Y = new_dataset['Class']

# %%
print(X)
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 10601  17708 -1.147207  1.403443  1.039369  1.190107  0.544046  1.963182
# 2366    1911  1.550736 -1.044668  0.388104 -1.721063 -1.100930  0.208485
# 3229    2796 -0.458806  0.600392  1.174742 -2.149494  0.294435 -0.832432
# 37099  38806 -0.789207  0.676912  1.951561  1.536374 -0.537135  1.570921
# 18728  29721  1.277573 -0.536155 -0.258179 -1.047285  1.192855  3.719173
# ...      ...       ...       ...       ...       ...       ...       ...
# 46909  42985 -4.075975  0.963031 -5.076070  4.955963 -0.161437 -2.832663
# 46918  42988 -4.423508  1.648048 -6.934388  4.894601 -5.078131  0.010849
# 46998  43028 -1.109646  0.811069 -1.138135  0.935265 -2.330248 -0.116106
# 47802  43369 -3.365319  2.426503 -3.752227  0.276017 -2.305870 -1.961578
# 48094  43494 -1.278138  0.716242 -1.143279  0.217805 -1.293890 -1.168952
#
#              V7        V8        V9  ...       V20       V21       V22  \
# ...

# %%
print(Y)
# Out:
# 10601    0.0
# 2366     0.0
# 3229     0.0
# 37099    0.0
# 18728    0.0
#         ...
# 46909    1.0
# 46918    1.0
# 46998    1.0
# 47802    1.0
# 48094    1.0
# Name: Class, Length: 296, dtype: float64

# %% [markdown]
# To split the data into training and testing data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
# 20% of data stored in test therefore 0.2 means 20%
# 80% of data stored in train

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (296, 30) (236, 30) (60, 30)

# %% [markdown]
# Model Training

# %% [markdown]
# Logistic Regression

# %%
model = LogisticRegression(max_iter=1000)  # Increase the number of iterations

# %%
# training the Logistic Regression Model with Training Data
model.fit(X_train,Y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %% [markdown]
# Model Evaluation

# %% [markdown]
# Accuracy Score

# %%
# accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  0.9872881355932204

# %%
# score above 75% or 80% are considered good

# %%
# accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
print('Accuracy on Test data : ', test_data_accuracy)
# Out:
# Accuracy on Test data :  0.9833333333333333

# %%
# our model is well fitted
# if percentages were not good, then model not well fitted or under-fitted or over-fitted
